# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %%
url = "https://www.amazon.in/s?k=hp+laptops&crid=1FWQE051LJTB0&sprefix=hp+laptop%2Caps%2C230&ref=nb_sb_noss_2"

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text,"html")
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
title = soup.find_all("span",attrs={"class":"a-size-medium a-color-base a-text-normal"})
title
# Out:
# [<span class="a-size-medium a-color-base a-text-normal">HP Laptop 15s, 12th Gen Intel Core i3, 15.6-inch (39.6 cm), 8GB DDR4, 512GB SSD, Thin &amp; Light, Dual Speakers (Win 11, MSO 2021, Silver, 1.69 kg), fq5007TU / FQ5327TU</span>,
#  <span class="a-size-medium a-color-base a-text-normal">HP 15s Core i5 12th Gen (16GB RAM/512GB SSD/FHD/MS Office 21 /Backlit Keyboard /15.6-inch (39.6 cm)/FHD/Windows 11/Silver/1.69 kg) fy5009TU/fd0111tu Laptop</span>,
#  <span class="a-size-medium a-color-base a-text-normal">HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (39.6 cm), FHD, 8GB DDR4, 512GB SSD, AMD Radeon Graphics, Thin &amp; Light, Dual Speakers (Win 11, MSO 2019, Silver, 1.69 kg), eq2143AU</span>,
#  <span class="a-size-medium a-color-base a-text-normal">HP 15s Core i3 12th Gen (8GB RAM/512 GB SSD/FHD/Windows 11/MS Office 21/15.6” (39.6cm)/Silver/1.69kg) fy5006TU Laptop</span>,
# ...

# %%
title
# Out:
# [<span class="a-size-medium a-color-base a-text-normal">HP Laptop 15s, 12th Gen Intel Core i3, 15.6-inch (39.6 cm), 8GB DDR4, 512GB SSD, Thin &amp; Light, Dual Speakers (Win 11, MSO 2021, Silver, 1.69 kg), fq5007TU / FQ5327TU</span>,
#  <span class="a-size-medium a-color-base a-text-normal">HP 15s Core i5 12th Gen (16GB RAM/512GB SSD/FHD/MS Office 21 /Backlit Keyboard /15.6-inch (39.6 cm)/FHD/Windows 11/Silver/1.69 kg) fy5009TU/fd0111tu Laptop</span>,
#  <span class="a-size-medium a-color-base a-text-normal">HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (39.6 cm), FHD, 8GB DDR4, 512GB SSD, AMD Radeon Graphics, Thin &amp; Light, Dual Speakers (Win 11, MSO 2019, Silver, 1.69 kg), eq2143AU</span>,
#  <span class="a-size-medium a-color-base a-text-normal">HP 15s Core i3 12th Gen (8GB RAM/512 GB SSD/FHD/Windows 11/MS Office 21/15.6” (39.6cm)/Silver/1.69kg) fy5006TU Laptop</span>,
# ...

# %%
t = [i.text.strip() for i in title]
print(t)
# Out:
# ['HP Laptop 15s, 12th Gen Intel Core i3, 15.6-inch (39.6 cm), 8GB DDR4, 512GB SSD, Thin & Light, Dual Speakers (Win 11, MSO 2021, Silver, 1.69 kg), fq5007TU / FQ5327TU', 'HP 15s Core i5 12th Gen (16GB RAM/512GB SSD/FHD/MS Office 21 /Backlit Keyboard /15.6-inch (39.6 cm)/FHD/Windows 11/Silver/1.69 kg) fy5009TU/fd0111tu Laptop', 'HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (39.6 cm), FHD, 8GB DDR4, 512GB SSD, AMD Radeon Graphics, Thin & Light, Dual Speakers (Win 11, MSO 2019, Silver, 1.69 kg), eq2143AU', 'HP 15s Core i3 12th Gen (8GB RAM/512 GB SSD/FHD/Windows 11/MS Office 21/15.6” (39.6cm)/Silver/1.69kg) fy5006TU Laptop', 'HP Laptop 255 G9 (2024), AMD Athlon Silver 3050U - (8GB/256GB SSD/AMD Radeon Graphics/Windows 11 Pro) Thin and Light Business Laptop/15.6" (39.62cm)/Black/1.47 kg/MS Office 2021 Pro Plus', 'HP Laptop 15s, AMD Ryzen 5 5500U, 15.6-inch (39.6 cm), FHD, 16GB DDR4, 512GB SSD, AMD Radeon Graphics, 720p HD Camera, Backlit KB, Thin & Light (Win 11, MSO 2021, Silver, 1.69 kg
# ...

# %%
import os

df = pd.DataFrame(columns = ["Product Name","Price"])

# %%
df["Product Name"] = t
df
# Out:
#                                          Product Name Price
# 0   HP Laptop 15s, 12th Gen Intel Core i3, 15.6-in...   NaN
# 1   HP 15s Core i5 12th Gen (16GB RAM/512GB SSD/FH...   NaN
# 2   HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (3...   NaN
# 3   HP 15s Core i3 12th Gen (8GB RAM/512 GB SSD/FH...   NaN
# 4   HP Laptop 255 G9 (2024), AMD Athlon Silver 305...   NaN
# 5   HP Laptop 15s, AMD Ryzen 5 5500U, 15.6-inch (3...   NaN
# 6   HP 15s Core i3 12th Gen (8GB RAM/512GB SSD/FHD...   NaN
# 7   HP 15 Core i5 13th Gen (16GB RAM/512GB SSD/FHD...   NaN
# 8   HP 15 Core i3 13th Gen (8GB RAM/512GB SSD/FHD/...   NaN
# 9   HP Laptop 15s, Intel Celeron N4500, 15.6-inch ...   NaN
# 10  HP Pavilion 14, 12th Gen Intel Core i5-1235U, ...   NaN
# 11  HP 15s Ryzen 5 5500U (8GB RAM/512GB SSD/FHD/Wi...   NaN
# 12  HP 15 Core i5 13th Gen (16GB RAM/512GB SSD/FHD...   NaN
# 13  HP 15 Core i3 13th Gen (8GB RAM/512GB SSD/FHD/...   NaN
# 14  HP 14s Core i3 12th Gen (8GB RAM/512GB SSD/FHD...   NaN
# ...

# %%
price = soup.find_all("span",attrs = {"class":"a-price-whole"})
price
# Out:
# [<span class="a-price-whole">37,990</span>,
#  <span class="a-price-whole">52,990</span>,
#  <span class="a-price-whole">31,990</span>,
#  <span class="a-price-whole">35,490</span>,
#  <span class="a-price-whole">24,490</span>,
#  <span class="a-price-whole">41,990</span>,
#  <span class="a-price-whole">36,990</span>,
#  <span class="a-price-whole">55,800</span>,
#  <span class="a-price-whole">39,490</span>,
#  <span class="a-price-whole">25,990</span>,
#  <span class="a-price-whole">61,990</span>,
#  <span class="a-price-whole">36,990</span>,
#  <span class="a-price-whole">54,990</span>,
#  <span class="a-price-whole">40,990</span>,
#  <span class="a-price-whole">36,890</span>,
#  <span class="a-price-whole">31,550</span>]

# %%
df["Price"] = p
df

df.to_csv(r"C:\Users\sharief\Documents\Saqib\data analyst\Python\HP laptops.csv")

# %%
pd.read_csv(r"C:\Users\sharief\Documents\Saqib\data analyst\Python\HP laptops.csv")
# Out:
#     Unnamed: 0                                       Product Name   Price
# 0            0  HP Laptop 15s, 12th Gen Intel Core i3, 15.6-in...  37,990
# 1            1  HP 15s Core i5 12th Gen (16GB RAM/512GB SSD/FH...  52,990
# 2            2  HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (3...  31,990
# 3            3  HP 15s Core i3 12th Gen (8GB RAM/512 GB SSD/FH...  35,490
# 4            4  HP Laptop 255 G9 (2024), AMD Athlon Silver 305...  23,990
# 5            5  HP Laptop 15s, AMD Ryzen 5 5500U, 15.6-inch (3...  41,990
# 6            6  HP 15s Core i3 12th Gen (8GB RAM/512GB SSD/FHD...  36,990
# 7            7  HP 15 Core i5 13th Gen (16GB RAM/512GB SSD/FHD...  55,800
# 8            8  HP 15 Core i3 13th Gen (8GB RAM/512GB SSD/FHD/...  39,490
# 9            9  HP Laptop 15s, Intel Celeron N4500, 15.6-inch ...  25,990
# 10          10  HP Pavilion 14, 12th Gen Intel Core i5-1235U, ...  61,990
# 11          11  HP 15s Ryzen 5 5500U (8GB RAM/512GB SSD/FHD/Wi...  36,990
# ...

# %%
rating = soup.find_all("a",attrs = {"class":"a-popover-trigger a-declarative"})
r = [i.text.strip() for i in rating]
r
# Out:
# ['4.0 out of 5 stars',
#  '3.6 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.0 out of 5 stars',
#  '3.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '3.7 out of 5 stars',
#  '3.7 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
df["Rating"] = r
df
# Out:
#                                          Product Name   Price  \
# 0   HP Laptop 15s, 12th Gen Intel Core i3, 15.6-in...  37,990
# 1   HP 15s Core i5 12th Gen (16GB RAM/512GB SSD/FH...  52,990
# 2   HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (3...  31,990
# 3   HP 15s Core i3 12th Gen (8GB RAM/512 GB SSD/FH...  35,490
# 4   HP Laptop 255 G9 (2024), AMD Athlon Silver 305...  23,990
# 5   HP Laptop 15s, AMD Ryzen 5 5500U, 15.6-inch (3...  41,990
# 6   HP 15s Core i3 12th Gen (8GB RAM/512GB SSD/FHD...  36,990
# 7   HP 15 Core i5 13th Gen (16GB RAM/512GB SSD/FHD...  55,800
# 8   HP 15 Core i3 13th Gen (8GB RAM/512GB SSD/FHD/...  39,490
# 9   HP Laptop 15s, Intel Celeron N4500, 15.6-inch ...  25,990
# 10  HP Pavilion 14, 12th Gen Intel Core i5-1235U, ...  61,990
# 11  HP 15s Ryzen 5 5500U (8GB RAM/512GB SSD/FHD/Wi...  36,990
# 12  HP 15 Core i5 13th Gen (16GB RAM/512GB SSD/FHD...  54,990
# 13  HP 15 Core i3 13th Gen (8GB RAM/512GB SSD/FHD/...  40,990
# ...

# %%
df["Rating"] = df["Rating"].str[:3]
df
# Out:
#                                          Product Name   Price Rating
# 0   HP Laptop 15s, 12th Gen Intel Core i3, 15.6-in...  37,990    4.0
# 1   HP 15s Core i5 12th Gen (16GB RAM/512GB SSD/FH...  52,990    3.6
# 2   HP Laptop 15s, AMD Ryzen 3 5300U, 15.6-inch (3...  31,990    4.1
# 3   HP 15s Core i3 12th Gen (8GB RAM/512 GB SSD/FH...  35,490    4.1
# 4   HP Laptop 255 G9 (2024), AMD Athlon Silver 305...  23,990    4.0
# 5   HP Laptop 15s, AMD Ryzen 5 5500U, 15.6-inch (3...  41,990    4.0
# 6   HP 15s Core i3 12th Gen (8GB RAM/512GB SSD/FHD...  36,990    4.1
# 7   HP 15 Core i5 13th Gen (16GB RAM/512GB SSD/FHD...  55,800    4.1
# 8   HP 15 Core i3 13th Gen (8GB RAM/512GB SSD/FHD/...  39,490    4.0
# 9   HP Laptop 15s, Intel Celeron N4500, 15.6-inch ...  25,990    3.1
# 10  HP Pavilion 14, 12th Gen Intel Core i5-1235U, ...  61,990    4.1
# 11  HP 15s Ryzen 5 5500U (8GB RAM/512GB SSD/FHD/Wi...  36,990    4.1
# 12  HP 15 Core i5 13th Gen (16GB RAM/512GB SSD/FHD...  54,990    3.7
# ...

# %%
df.to_csv(r"C:\Users\sharief\Documents\Saqib\data analyst\Python\HP laptops.csv")
